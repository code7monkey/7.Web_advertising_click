# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# 큰 CSV 파일의 경로
file_path = '/content/drive/MyDrive/웹 광고 클릭률/train.csv'

# CSV 파일의 일부(처음 1000행)만 읽기
chunk_size = 2000000
chunk = pd.read_csv(file_path, nrows=chunk_size)

# 추출한 데이터 저장
output_path = '/content/drive/MyDrive/웹 광고 클릭률/semi_train.csv'
chunk.to_csv(output_path, index=False)

print(f"추출된 데이터가 {output_path}에 저장되었습니다.")
# Out:
# 추출된 데이터가 /content/drive/MyDrive/웹 광고 클릭률/semi_train.csv에 저장되었습니다.
